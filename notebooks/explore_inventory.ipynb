# %%
from pathlib import Path
from importlib import reload
import sys

PROJECT_ROOT = Path.cwd().parents[0]  # notebooks/ -> project root
sys.path.append(str(PROJECT_ROOT))

import pandas as pd
import etl.clean as clean
from etl.ingest import load_inventory
import etl.formatter as formatter

reload(clean)
reload(formatter)

df = load_inventory()
df_cleaned = clean.remove_first_row(df)
df_cleaned = clean.rename_inventory_columns(df_cleaned)
df_cleaned = clean.remove_empty_values(df_cleaned)
df_cleaned = clean.remove_status_column(df_cleaned)
df_cleaned = clean.convert_inventory_types(df_cleaned)

df_formatter = formatter.format_inventory_cables(df_cleaned)


print(df_formatter)
# Out:
#                                     material  \
# 1   Fibra Óptica Duplex MM OM4 LC-UPC/LC-UPC
# 2   Fibra Óptica Duplex MM OM4 LC-UPC/LC-UPC
# 3   Fibra Óptica Duplex MM OM4 LC-UPC/LC-UPC
# 4   Fibra Óptica Duplex MM OM4 LC-UPC/LC-UPC
# 5   Fibra Óptica Duplex MM OM4 LC-UPC/LC-UPC
# ..                                       ...
# 90                                   Insumos
# 91                                   Insumos
# 92                                   Insumos
# 93                                   Insumos
# 94                                   Insumos
#
#                                          cable_length  quantity  min_quantity
# 1            Fibra Óptica Duplex MM OM4 LC-UPC/LC-UPC       NaN           NaN
# 2                                          1.5 metros      11.0          10.0
# 3                                          3.0 metros      10.0          10.0
# 4                                          5.0 metros      10.0          10.0
# 5                                         10.0 metros       8.0          10.0
# ..                                                ...       ...           ...
# 90                 Cordão Óptico SM MPO-APC FONNET 3M       1.0           1.0
# 91                  Cordão Óptico SM LC-UPC FONNET 3M       1.0           1.0
# 92  Cordão Óptico - CODECOM - 1-MT-2F-SMA1-LSZH-14...       2.0           1.0
# 93  Cordão Óptico - CODECOM - 2.5-MT-2F-SMA1-LSZH-...       2.0           1.0
# 94  Cordão Óptico - CODECOM - 5-MT-2F-SMA1-LSZH-14...       2.0           1.0
#
# [87 rows x 4 columns]
