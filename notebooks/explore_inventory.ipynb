# %%
from pathlib import Path
from importlib import reload
import sys

PROJECT_ROOT = Path.cwd().parents[0]  # notebooks/ -> project root
sys.path.append(str(PROJECT_ROOT))

import pandas as pd
import etl.clean as clean
from etl.ingest import load_inventory
import etl.formatter as formatter

reload(clean)
reload(formatter)

df = load_inventory()
df_cleaned = clean.remove_first_row(df)
df_cleaned = clean.rename_inventory_columns(df_cleaned)
df_cleaned = clean.remove_status_column(df_cleaned)
df_cleaned = clean.convert_inventory_types(df_cleaned)

df_formatter = formatter.format_inventory_cables(df_cleaned)
df_cleaned = clean.remove_empty_values(df_formatter)


print(df_cleaned.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 37 entries, 2 to 46
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   material      37 non-null     object
#  1   cable_length  37 non-null     Float64
#  2   quantity      37 non-null     float64
#  3   min_quantity  37 non-null     float64
# dtypes: Float64(1), float64(2), object(1)
# memory usage: 1.5+ KB
# None
